# %%
import argparse
import os
import random
from collections import defaultdict

import cv2
import re

import numpy as np
from PIL import Image
import torch
import html
import gradio as gr

import torchvision.transforms as T
import torch.backends.cudnn as cudnn

from minigpt4.common.config import Config

from minigpt4.common.registry import registry
from minigpt4.conversation.conversation import Conversation, SeparatorStyle, Chat

# imports modules for registration
from minigpt4.datasets.builders import *
from minigpt4.models import *
from minigpt4.processors import *
from minigpt4.runners import *
from minigpt4.tasks import *

# %%
class CommandLineArguments:
    def __init__(self, cfg_path='eval_configs/minigptv2_eval.yaml', gpu_id=0, options=None):
        self.cfg_path = cfg_path
        self.gpu_id = gpu_id
        self.options = options

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

cudnn.benchmark = False
cudnn.deterministic = True

# %%
print('Initializing Chat')
args = CommandLineArguments()
cfg = Config(args)

device = 'cuda:{}'.format(args.gpu_id)

model_config = cfg.model_cfg
model_config.device_8bit = args.gpu_id
model_cls = registry.get_model_class(model_config.arch)
model = model_cls.from_config(model_config).to(device)
bounding_box_size = 100

vis_processor_cfg = cfg.datasets_cfg.cc_sbu_align.vis_processor.train
vis_processor = registry.get_processor_class(vis_processor_cfg.name).from_config(vis_processor_cfg)

model = model.eval()

CONV_VISION = Conversation(
    system="",
    roles=(r"<s>[INST] ", r" [/INST]"),
    messages=[],
    offset=2,
    sep_style=SeparatorStyle.SINGLE,
    sep="",
)
# Out:
# Initializing Chat
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# trainable params: 33,816,576 || all params: 6,772,232,192 || trainable%: 0.49934165045237716
# Position interpolate from 16x16 to 32x32
# Load Minigpt-4-LLM Checkpoint: minigpt4/outputs/20240416202/checkpoint_1.pth

# %%
def gradio_reset(chat_state, img_list):
    if chat_state is not None:
        chat_state.messages = []
    if img_list is not None:
        img_list = []
    return None, gr.update(value=None, interactive=True), gr.update(placeholder='Upload your image and chat',
                                                                    interactive=True), chat_state, img_list


def image_upload_trigger(upload_flag, replace_flag, img_list):
    # set the upload flag to true when receive a new image.
    # if there is an old image (and old conversation), set the replace flag to true to reset the conv later.
    upload_flag = 1
    if img_list:
        replace_flag = 1
    return upload_flag, replace_flag


def example_trigger(text_input, image, upload_flag, replace_flag, img_list):
    # set the upload flag to true when receive a new image.
    # if there is an old image (and old conversation), set the replace flag to true to reset the conv later.
    upload_flag = 1
    if img_list or replace_flag == 1:
        replace_flag = 1

    return upload_flag, replace_flag


def gradio_ask(user_message, chatbot, chat_state, gr_img, img_list, upload_flag, replace_flag):
    if len(user_message) == 0:
        text_box_show = 'Input should not be empty!'
    else:
        text_box_show = ''

    if isinstance(gr_img, dict):
        gr_img, mask = gr_img['image'], gr_img['mask']
    else:
        mask = None

    if '[identify]' in user_message:
        # check if user provide bbox in the text input
        integers = re.findall(r'-?\d+', user_message)
        if len(integers) != 4:  # no bbox in text
            bbox = mask2bbox(mask)
            user_message = user_message + bbox

    if chat_state is None:
        chat_state = CONV_VISION.copy()

    if upload_flag:
        if replace_flag:
            chat_state = CONV_VISION.copy()  # new image, reset everything
            replace_flag = 0
            chatbot = []
        img_list = []
        llm_message = chat.upload_img(gr_img, chat_state, img_list)
        upload_flag = 0

    chat.ask(user_message, chat_state)

    chatbot = chatbot + [[user_message, None]]

    if '[identify]' in user_message:
        visual_img, _ = visualize_all_bbox_together(gr_img, user_message)
        if visual_img is not None:
            file_path = save_tmp_img(visual_img)
            chatbot = chatbot + [[(file_path,), None]]

    return text_box_show, chatbot, chat_state, img_list, upload_flag, replace_flag


def gradio_answer(chatbot, chat_state, img_list, temperature):
    llm_message = chat.answer(conv=chat_state,
                              img_list=img_list,
                              temperature=temperature,
                              max_new_tokens=500,
                              max_length=2000)[0]
    chatbot[-1][1] = llm_message
    return chatbot, chat_state


def gradio_stream_answer(chatbot, chat_state, img_list, temperature):
    if len(img_list) > 0:
        if not isinstance(img_list[0], torch.Tensor):
            chat.encode_img(img_list)
    streamer = chat.stream_answer(conv=chat_state,
                                  img_list=img_list,
                                  temperature=temperature,
                                  max_new_tokens=500,
                                  max_length=2000)
    output = ''
    for new_output in streamer:
        escapped = escape_markdown(new_output)
        output += escapped
        chatbot[-1][1] = output
        yield chatbot, chat_state
    chat_state.messages[-1][1] = '</s>'
    return chatbot, chat_state

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from PIL import Image
import nltk
import numpy as np
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize
import Levenshtein
import json

transform = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.ToTensor(),
])

# %%
with open('medvqa_dataset/Slake/Slake1.0/test_en_w_captions_medicap.json', 'r', encoding='utf-8') as f:
        data = json.load(f)

# %%
vis_root = 'medvqa_dataset/Slake/Slake1.0/imgs'

# %%
chat = Chat(model, vis_processor, device=device)

# %%
num_beams = 1
temperature = 0.6
new_obj = []
bleu_scores = []
meteor_scores = []
levenshtein_similarities = []
try:
    if chat_state is not None:
        chat_state.messages = []
    if img_list is not None:
        img_list = []
except:
    pass
for obj in data:
    image_path = os.path.join(vis_root, obj['img_name'])
    image = Image.open(image_path).convert("RGB")
    img = transform(image)
    
    chat_state = CONV_VISION.copy()
    img_list = []
    llm_message = chat.upload_img(img, chat_state, img_list)
    chat.encode_img(img_list)
    
    # user_message = f'Answer the question succinctly and directly, avoiding any details or explanations. Your answers should be straight to the point and as short as possible: {obj["question"]}'
    # user_message = f"Based on the image and the following caption {obj['question']} Answer the following question: {obj['caption']}"
    user_message = "Take this caption into account but don't rely on it solely '{}' {}".format(obj['caption'], obj['question'])
    chat.ask(user_message, chat_state)
    
    llm_message = chat.answer(conv=chat_state,
                              img_list=img_list,
                              num_beams=num_beams,
                              temperature=temperature,
                              max_new_tokens=300,
                              max_length=2000)[0]
    
    
    real_answer = obj['answer']
    
    new_obj.append({'question': obj["question"],
                 'pred': llm_message,
                 'gt': real_answer,
                 'answer_type': obj['answer_type']})
    
    print('Q: ', user_message[59:])
    print('A\': ', llm_message)
    print('A: ', real_answer)
    print()
    
    chat_state.messages = []
    img_list = []
# Out:
# Q:  'Computed tomography scan of the chest showing a nodular opacity in the left lung.' What modality is used to take this image?
# A':  theBXL-1 and 2s2 Venti (D Ch. on'kina-flest, orash’N-o 1 (As0c.(pp (D 1 and a H the BOMGbetation to 1 and 1 and 1 and take'ok field-39A Anone/w.hub, g,", of, orase asbagger 1 and be_bro-39a, reelim / dM-31 and 1 and to 1 and 1 and be_9A An’in’ in a and to 2ch 1 and be_statid the B.Ћp> publicof many for - the situation. in a and 1 (As02brri is 1 and 1 and 1 and a: (D Ch. PAd Center (DOn theBxna (DCh.'shave (DTo4amer (Dxna and 1 and 1 and to 1 and 1 and 578n1 and to 1 and a future2brret peri-2se (DOn GI-fl�es.Ћ fiary De. 1 and be_fl(com, reCollections 1 and 1 and 2s two-o, or c: (As01 and be_freter and to 1 and
# A:  CT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 29
#      26 user_message = "Take this caption into account but don't rely on it solely '{}' {}".format(obj['caption'], obj['question'])
#      27 chat.ask(user_message, chat_state)
# ---> 29 llm_message = chat.answer(conv=chat_state,
#      30                           img_list=img_list,
#      31                           num_beams=num_beams,
#      32                           temperature=temperature,
#      33                           max_new_tokens=300,
#      34                           max_length=2000)[0]
#      37 real_answer = obj['answer']
#      39 new_obj.append({'question': obj["question"],
#      40              'pred': llm_message,
#      41              'gt': real_answer,
#      42              'answer_type': obj['answer_type']})
#
# File /ibex/user/sabbam0a/grad/MiniGPT-4/minigpt4/conversation/conversation.py:187, in Chat.answer(self, conv, img_list, **kargs)
#     185 def answer(self, conv, img_list, **kargs):
#     186     generation_dict = self.answer_prepare(conv, img_list, **kargs)
# --> 187     output_token = self.model_generate(**generation_dict)[0]
#     188     output_text = self.model.llama_tokenizer.decode(output_token, skip_special_tokens=True)
#     190     output_text = output_text.split('###')[0]  # remove the stop sign '###'
#
# File /ibex/user/sabbam0a/grad/MiniGPT-4/minigpt4/conversation/conversation.py:207, in Chat.model_generate(self, *args, **kwargs)
#     204 def model_generate(self, *args, **kwargs):
#     205     # for 8 bit and 16 bit compatibility
#     206     with self.model.maybe_autocast():
# --> 207         output = self.model.llama_model.generate(*args, **kwargs)
#     208     return output
#
# File ~/miniconda3/lib/python3.11/site-packages/peft/peft_model.py:1190, in PeftModelForCausalLM.generate(self, *args, **kwargs)
#    1188     with self._enable_peft_forward_hooks(*args, **kwargs):
#    1189         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1190         outputs = self.base_model.generate(*args, **kwargs)
#    1191 else:
#    1192     outputs = self.base_model.generate(**kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/generation/utils.py:1525, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1517     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1518         input_ids=input_ids,
#    1519         expand_size=generation_config.num_return_sequences,
#    1520         is_encoder_decoder=self.config.is_encoder_decoder,
#    1521         **model_kwargs,
#    1522     )
#    1524     # 13. run sample
# -> 1525     return self.sample(
#    1526         input_ids,
#    1527         logits_processor=prepared_logits_processor,
#    1528         logits_warper=logits_warper,
#    1529         stopping_criteria=prepared_stopping_criteria,
#    1530         pad_token_id=generation_config.pad_token_id,
#    1531         eos_token_id=generation_config.eos_token_id,
#    1532         output_scores=generation_config.output_scores,
#    1533         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1534         synced_gpus=synced_gpus,
#    1535         streamer=streamer,
#    1536         **model_kwargs,
#    1537     )
#    1539 elif generation_mode == GenerationMode.BEAM_SEARCH:
#    1540     # 11. prepare beam search scorer
#    1541     beam_scorer = BeamSearchScorer(
#    1542         batch_size=batch_size,
#    1543         num_beams=generation_config.num_beams,
#    (...)
#    1548         max_length=generation_config.max_length,
#    1549     )
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/generation/utils.py:2622, in GenerationMixin.sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2619 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2621 # forward pass to get next token
# -> 2622 outputs = self(
#    2623     **model_inputs,
#    2624     return_dict=True,
#    2625     output_attentions=output_attentions,
#    2626     output_hidden_states=output_hidden_states,
#    2627 )
#    2629 if synced_gpus and this_peer_finished:
#    2630     continue  # don't waste resources running the code we don't need
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     163         output = module._old_forward(*args, **kwargs)
#     164 else:
# --> 165     output = module._old_forward(*args, **kwargs)
#     166 return module._hf_hook.post_forward(module, output)
#
# File /ibex/user/sabbam0a/grad/MiniGPT-4/minigpt4/models/modeling_llama.py:65, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, reduction)
#      62 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#      64 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# ---> 65 outputs = self.model(
#      66     input_ids=input_ids,
#      67     attention_mask=attention_mask,
#      68     position_ids=position_ids,
#      69     past_key_values=past_key_values,
#      70     inputs_embeds=inputs_embeds,
#      71     use_cache=use_cache,
#      72     output_attentions=output_attentions,
#      73     output_hidden_states=output_hidden_states,
#      74     return_dict=return_dict,
#      75 )
#      77 hidden_states = outputs[0]
#      78 if hasattr(self.config, 'pretraining_tp') and self.config.pretraining_tp > 1:
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     163         output = module._old_forward(*args, **kwargs)
#     164 else:
# --> 165     output = module._old_forward(*args, **kwargs)
#     166 return module._hf_hook.post_forward(module, output)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:1070, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1060     layer_outputs = self._gradient_checkpointing_func(
#    1061         decoder_layer.__call__,
#    1062         hidden_states,
#    (...)
#    1067         use_cache,
#    1068     )
#    1069 else:
# -> 1070     layer_outputs = decoder_layer(
#    1071         hidden_states,
#    1072         attention_mask=attention_mask,
#    1073         position_ids=position_ids,
#    1074         past_key_value=past_key_values,
#    1075         output_attentions=output_attentions,
#    1076         use_cache=use_cache,
#    1077     )
#    1079 hidden_states = layer_outputs[0]
#    1081 if use_cache:
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     163         output = module._old_forward(*args, **kwargs)
#     164 else:
# --> 165     output = module._old_forward(*args, **kwargs)
#     166 return module._hf_hook.post_forward(module, output)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:798, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     795 hidden_states = self.input_layernorm(hidden_states)
#     797 # Self Attention
# --> 798 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     799     hidden_states=hidden_states,
#     800     attention_mask=attention_mask,
#     801     position_ids=position_ids,
#     802     past_key_value=past_key_value,
#     803     output_attentions=output_attentions,
#     804     use_cache=use_cache,
#     805     **kwargs,
#     806 )
#     807 hidden_states = residual + hidden_states
#     809 # Fully Connected
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     163         output = module._old_forward(*args, **kwargs)
#     164 else:
# --> 165     output = module._old_forward(*args, **kwargs)
#     166 return module._hf_hook.post_forward(module, output)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:695, in LlamaSdpaAttention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     693 query_states = self.q_proj(hidden_states)
#     694 key_states = self.k_proj(hidden_states)
# --> 695 value_states = self.v_proj(hidden_states)
#     697 query_states = query_states.view(bsz, q_len, self.num_heads, self.head_dim).transpose(1, 2)
#     698 key_states = key_states.view(bsz, q_len, self.num_key_value_heads, self.head_dim).transpose(1, 2)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/lib/python3.11/site-packages/peft/tuners/lora/bnb.py:236, in Linear8bitLt.forward(self, x, *args, **kwargs)
#     234     output = lora_B(lora_A(dropout(x))) * scaling
#     235 else:
# --> 236     output = self._apply_dora(x, lora_A, lora_B, scaling, active_adapter)
#     237 if requires_conversion:
#     238     output = output.to(expected_dtype)
#
# File ~/miniconda3/lib/python3.11/site-packages/peft/tuners/lora/layer.py:214, in LoraLayer._apply_dora(self, x, lora_A, lora_B, scaling, active_adapter)
#     212 weight = self.get_base_layer().weight
#     213 quant_state = getattr(self.get_base_layer(), "state", None)
# --> 214 weight = dequantize_bnb_weight(weight, state=quant_state)  # no-op if not bnb
#     215 weight = weight.to(x.dtype)
#     216 weight_norm = self._get_weight_norm(weight, lora_weight, scaling)
#
# File ~/miniconda3/lib/python3.11/site-packages/peft/utils/integrations.py:63, in dequantize_bnb_weight(weight, state)
#      60 if state.SCB is None:
#      61     state.SCB = weight.SCB
# ---> 63 im = torch.eye(weight.data.shape[-1]).contiguous().half().to(weight.device)
#      64 im, imt, SCim, SCimt, coo_tensorim = bnb.functional.double_quant(im)
#      65 im, Sim = bnb.functional.transform(im, "col32")
#
# KeyboardInterrupt:

# %%
with open('test_slake_finetune_w_mid_proj_w_caption_medicap_1.json', "w") as json_file:
    json.dump(new_obj, json_file, indent=4)

# %%
###GEMENI

# %%
with open('test_slake_finetune_w_mid_proj_w_caption_medicap_1.json', 'r', encoding='utf-8') as f:
        data = json.load(f)

# %%
import vertexai
from vertexai.generative_models import GenerativeModel, Part

def generate_text(txt) -> str:#project_id: str, location: str) -> str:
    multimodal_model = GenerativeModel("gemini-1.0-pro")
    response = multimodal_model.generate_content(txt)
    return response.text

# %%
yes_no = []

# %%
for i, obj in enumerate(data):
    input_text = f"""
    You are an assistant who's job is to post-process outputs from an LLM. The LLM is designed
    to tackle a medical visual question answering task. The outputs of the model are very long and
    detailed, while the ground truth answers are very short. For example, a question like 'Which organ
    is abnormal, heart or lung?' should have the very short answer 'Lung', but the model's output is
    'The lungs are abnormal in this image.'. Another example is a question like 'Where is the abnormality
    in this image?', and the real answer would be 'Upper Left Lung', but the model output would be something
    like 'The abnormality is in the upper left lung, where there is an area of consolidation. This is a
    possible example of pneumonia. However, other possibilities include pulmonary embolism,
    pneumothorax, and pleural effusion, among others.'. This extra information is not needed at all.
    If part of the predicted answer is in the ground truth or vice versa, then consider it correct.

    Now the question at hand is: {obj['question']}
    Your job here is to output 'Yes' if both the model output and the ground truth are semantically the same, and 'No' otherwise.
    Model output: {obj['pred']}
    Ground truth: {obj['gt']}
    """
    try:
        corrected_pred = generate_text(input_text)
    except e:
        print(e)
        corrected_pred = 'No'
    print('PRED: ', obj['pred'])
    print('GT: ', obj['gt'])
    print('Y/N : ', corrected_pred)
    print()
    yes_no.append(corrected_pred)
# Out:
# PRED:  ct
# GT:  CT
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung, Spinal Cord
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  chronic obstructive pulmonary disease and pneumonia
# GT:  Lung Cancer
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right lung
# GT:  Left Lung, Right
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  ct
# GT:  CT
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Lung
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  lung cancer and pneumothorax
# GT:  Lung Cancer
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right lung
# GT:  Left Lung, Right
# Y/N :  No
#
# PRED:  heart
# GT:  Lung
# Y/N :  No
#
# PRED:  ct scan
# GT:  CT
# Y/N :  Yes
#
# PRED:  thorax
# GT:  Chest
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  chronic obstructive pulmonary disease and lung cancer
# GT:  Lung Cancer
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  left lower lobe
# GT:  Right Lung, Left
# Y/N :  Yes
#
# PRED:  x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  pneumonia
# GT:  Cardiomegaly
# Y/N :  No
#
# PRED:  right lung
# GT:  Center
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  lung
# GT:  Heart
# Y/N :  No
#
# PRED:  mri
# GT:  MRI
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  t2 weighted
# GT:  T2
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  ct scan
# GT:  X-Ray
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  chronic obstructive pulmonary disease copd and pneumonia
# GT:  Pneumonia
# Y/N :  Yes
#
# PRED:  bilateral lower lobes
# GT:  Left Lung, Lower Right
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  ct scan
# GT:  X-Ray
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  pneumonia
# GT:  Cardiomegaly
# Y/N :  No
#
# PRED:  right hemithorax
# GT:  Center
# Y/N :  No
#
# PRED:  heart
# GT:  Heart
# Y/N :  Yes
#
# PRED:  x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  pneumonia and cancer
# GT:  Cardiomegaly
# Y/N :  No
#
# PRED:  mediastinum
# GT:  Center
# Y/N :  No
#
# PRED:  both
# GT:  Heart
# Y/N :  No
#
# PRED:  ct
# GT:  X-Ray
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  pneumonia and emphysema
# GT:  Atelectasis, Mass
# Y/N :  No
#
# PRED:  lungs
# GT:  Right Lung
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  heart
# GT:  Lung
# Y/N :  No
#
# PRED:  pneumonia
# GT:  Cardiomegaly
# Y/N :  No
#
# PRED:  chest
# GT:  Center
# Y/N :  No
#
# PRED:  lung
# GT:  Heart
# Y/N :  No
#
# PRED:  ct scan
# GT:  X-Ray
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Lung
# Y/N :  No
#
# PRED:  chronic bronchitis and pneumonia
# GT:  Cardiomegaly
# Y/N :  No
#
# PRED:  right lower lobe
# GT:  Center
# Y/N :  No
#
# PRED:  lung
# GT:  Heart
# Y/N :  No
#
# PRED:  ct scan
# GT:  X-Ray
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  pulmonary fibrosis
# GT:  Nodule
# Y/N :  No
#
# PRED:  right side
# GT:  Left Lung, Right
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  heart
# GT:  Lung
# Y/N :  No
#
# PRED:  chest x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  pneumonia and cancer
# GT:  Nodule
# Y/N :  Yes
#
# PRED:  thorax
# GT:  Right Lung, Left
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  ct scan
# GT:  X-Ray
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  heart
# GT:  Lung
# Y/N :  No
#
# PRED:  pneumonia and emphysema
# GT:  Atelectasis
# Y/N :  No
#
# PRED:  right lung
# GT:  Right Lung, Lower Left
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  heart
# GT:  Lung
# Y/N :  No
#
# PRED:  bilateral pulmonary infiltrates
# GT:  Pneumonia
# Y/N :  Yes
#
# PRED:  bilateral lungs
# GT:  Left Lung, Right
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  t2 weighted
# GT:  MRI
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  t2 weighted
# GT:  T2
# Y/N :  Yes
#
# PRED:  one
# GT:  1
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  heart
# GT:  Lung
# Y/N :  No
#
# PRED:  pneumonia and metastatic disease
# GT:  Pneumothorax
# Y/N :  No
#
# PRED:  right lower lobe
# GT:  Right Lung, Left
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  ct scan
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right
# GT:  Left
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  liver
# GT:  Left Kidney
# Y/N :  No
#
# PRED:  kidney
# GT:  Liver
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  ct scan
# GT:  CT
# Y/N :  Yes
#
# PRED:  chest
# GT:  Abdomen
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  one
# GT:  4
# Y/N :  No
#
# PRED:  spleen
# GT:  Lung
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  right
# GT:  Top
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Left Lung
# Y/N :  No
#
# PRED:  lung
# GT:  Right Lung
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  ct
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  left
# GT:  Left
# Y/N :  Yes
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Spleen
# Y/N :  Yes
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  ct scan
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  nephrolithiasis and metastasis
# GT:  Liver Cancer
# Y/N :  No
#
# PRED:  right
# GT:  Left and top
# Y/N :  No
#
# PRED:  left hepatic lobe
# GT:  Liver
# Y/N :  Yes
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Spleen
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  ct
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  left
# GT:  Left and top
# Y/N :  Yes
#
# PRED:  left lobe
# GT:  Liver
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Spleen
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Spleen
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  t2-weighted
# GT:  MRI
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  t2
# GT:  T1
# Y/N :  No
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  ct
# GT:  MRI
# Y/N :  No
#
# PRED:  chest
# GT:  Abdomen
# Y/N :  No
#
# PRED:  csf
# GT:  T1
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right upper quadrant
# GT:  Not seen
# Y/N :  No
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  ct
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Lung
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  neuroendocrine tumor and metastasis
# GT:  Liver Cancer
# Y/N :  No
#
# PRED:  left
# GT:  Upper Left
# Y/N :  No
#
# PRED:  left hepatic lobe
# GT:  Liver
# Y/N :  Yes
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  liver
# GT:  Right Lung
# Y/N :  No
#
# PRED:  spleen
# GT:  Heart and Liver
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  calcifications
# GT:  Pulmonary bronchus
# Y/N :  No
#
# PRED:  right
# GT:  Symmetrical to the bone marrow
# Y/N :  No
#
# PRED:  ct
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  non-small cell lung cancer and chronic obstructive pulmonary disease
# GT:  Liver Cancer
# Y/N :  No
#
# PRED:  left renal vein
# GT:  Liver
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  spleen
# GT:  Spleen
# Y/N :  Yes
#
# PRED:  lung
# GT:  Liver
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  irregular
# GT:  Irregular
# Y/N :  Yes
#
# PRED:  right kidney
# GT:  Symmetrical to the bone marrow
# Y/N :  No
#
# PRED:  ct scan
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right
# GT:  Left
# Y/N :  No
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Right Lung
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  calcifications
# GT:  Pulmonary bronchus
# Y/N :  No
#
# PRED:  ct
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Small Bowel
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  liver
# GT:  Large Bowel
# Y/N :  No
#
# PRED:  spleen
# GT:  Large Bowel
# Y/N :  No
#
# PRED:  spleen
# GT:  Small Bowel
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  right kidney
# GT:  Symmetrical to the bone marrow
# Y/N :  No
#
# PRED:  ct scan
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  liver
# GT:  Large Bowel
# Y/N :  No
#
# PRED:  liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  liver
# GT:  Right Lung
# Y/N :  No
#
# PRED:  liver
# GT:  Stomach
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  liver
# GT:  Large Bowel
# Y/N :  No
#
# PRED:  ct scan
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  right lung
# GT:  Large Bowel
# Y/N :  No
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  spleen
# GT:  Right Lung
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse  Plane
# Y/N :  Yes
#
# PRED:  right lung
# GT:  Large Bowel
# Y/N :  No
#
# PRED:  chest x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  coronal
# GT:  Coronal Plane
# Y/N :  Yes
#
# PRED:  anterior
# GT:  Chest
# Y/N :  No
#
# PRED:  right
# GT:  Right
# Y/N :  Yes
#
# PRED:  left
# GT:  Upper Right Lung
# Y/N :  No
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  right lower lobe
# GT:  Breathe
# Y/N :  No
#
# PRED:  cough
# GT:  Chest pain, dyspnea
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right lower lobe
# GT:  Lower Right Lung
# Y/N :  Yes
#
# PRED:  right lung
# GT:  Lower Right Lung
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  emphysema
# GT:  Atelectasis
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  lung
# GT:  Breathe
# Y/N :  Yes
#
# PRED:  pneumonia
# GT:  Bronchial obstruction
# Y/N :  No
#
# PRED:  lungs
# GT:  Heart
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right
# GT:  Left
# Y/N :  No
#
# PRED:  right lung
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  pneumonia
# GT:  Pulmonary Mass
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  1
# Y/N :  Yes
#
# PRED:  minimal
# GT:  A Little
# Y/N :  Yes
#
# PRED:  vaccination
# GT:  Keep healthy
# Y/N :  No
#
# PRED:  lungs
# GT:  Heart
# Y/N :  No
#
# PRED:  chest x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right lung
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  right hemi-thorax
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  concave
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  minimal
# GT:  A Little
# Y/N :  No
#
# PRED:  antibiotics
# GT:  Physical therapy, surgical treatment
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  mediastinum
# GT:  Coronal Plane
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right
# GT:  Right
# Y/N :  Yes
#
# PRED:  bilateral
# GT:  Right Lung
# Y/N :  No
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  pneumonia
# GT:  Pneumonia
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  liver
# GT:  Breathe
# Y/N :  No
#
# PRED:  right lower lobe
# GT:  Medical therapy, supportive therapy
# Y/N :  No
#
# PRED:  lungs
# GT:  Heart
# Y/N :  No
#
# PRED:  chest x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  transverse
# GT:  Coronal Plane
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  left lung
# GT:  Heart
# Y/N :  No
#
# PRED:  right
# GT:  Heart
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  cf and pneumonia
# GT:  Cardiomegaly
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  lungs
# GT:  Breathe
# Y/N :  No
#
# PRED:  shortness of breath
# GT:  Chest tightness, arrhythmia
# Y/N :  No
#
# PRED:  lungs
# GT:  Heart
# Y/N :  No
#
# PRED:  chest x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  thorax
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right lower lobe
# GT:  Left
# Y/N :  No
#
# PRED:  right
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  pneumonia and lung cancer
# GT:  Pulmonary Infiltration
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  2
# GT:  2
# Y/N :  Yes
#
# PRED:  right lower lobe
# GT:  Breathe
# Y/N :  No
#
# PRED:  a chest x-ray
# GT:  Live healthy, enhance physical fitness
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  ct
# GT:  X-Ray
# Y/N :  No
#
# PRED:  coronal
# GT:  Coronal Plane
# Y/N :  Yes
#
# PRED:  cranial
# GT:  Chest
# Y/N :  No
#
# PRED:  left lower lobe
# GT:  Lower Left Lung
# Y/N :  Yes
#
# PRED:  left lower lobe
# GT:  Lower Left Lung
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  concave
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  lung
# GT:  Breathe
# Y/N :  Yes
#
# PRED:  antibiotics
# GT:  Medical treatment, surgical treatment
# Y/N :  No
#
# PRED:  heart
# GT:  Heart
# Y/N :  Yes
#
# PRED:  ct scan
# GT:  X-Ray
# Y/N :  No
#
# PRED:  transverse
# GT:  Coronal Plane
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right lung
# GT:  Upper Right Lung
# Y/N :  Yes
#
# PRED:  right lower lobe
# GT:  Upper Right Lung
# Y/N :  No
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  opaque
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  lung
# GT:  Breathe
# Y/N :  Yes
#
# PRED:  cough
# GT:  Chest tightness, fatigue
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  right lung
# GT:  Upper Left Lung
# Y/N :  No
#
# PRED:  right
# GT:  Upper Left Lung
# Y/N :  No
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  1
# GT:  2
# Y/N :  No
#
# PRED:  none
# GT:  A Little
# Y/N :  No
#
# PRED:  antibiotics
# GT:  Medical therapy, supportive therapy
# Y/N :  No
#
# PRED:  lungs
# GT:  Heart
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  anterior-posterior
# GT:  Coronal Plane
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right side
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  right side
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  1
# Y/N :  Yes
#
# PRED:  right upper lobe
# GT:  Promote blood flow
# Y/N :  No
#
# PRED:  pneumothorax
# GT:  Chest injury, lung disease, bullae
# Y/N :  No
#
# PRED:  lungs
# GT:  Heart
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  coronal
# GT:  Coronal Plane
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right lung
# GT:  Left Lung
# Y/N :  No
#
# PRED:  right lower lobe
# GT:  Left Lung
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  2
# GT:  2
# Y/N :  Yes
#
# PRED:  heart
# GT:  Breathe
# Y/N :  No
#
# PRED:  not smoking
# GT:  Quit smoking, enhance physical fitness
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  anterior
# GT:  Coronal Plane
# Y/N :  No
#
# PRED:  right anterior chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right
# GT:  Left
# Y/N :  No
#
# PRED:  right lower lobe
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  lungs
# GT:  Chest
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  opacities
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  right lower lobe
# GT:  Promote blood flow
# Y/N :  No
#
# PRED:  chemotherapy
# GT:  Medical therapy, supportive therapy
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  chest x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  right
# GT:  Chest
# Y/N :  No
#
# PRED:  right lower lobe
# GT:  Upper Right Lung
# Y/N :  Yes
#
# PRED:  right lower lobe
# GT:  Upper Right Lung
# Y/N :  Yes
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  gray
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  1
# Y/N :  Yes
#
# PRED:  heart
# GT:  Breathe
# Y/N :  No
#
# PRED:  smoking
# GT:  Pay attention to prevent cold and keep warm, enhance physical fitness
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  lateral
# GT:  X-Ray
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right
# GT:  Right
# Y/N :  Yes
#
# PRED:  right lower lobe
# GT:  Lower Right Lung
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  pneumonia
# GT:  Pneumonia
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  right lower lobe atelectasis
# GT:  Promote blood flow
# Y/N :  No
#
# PRED:  radiation therapy
# GT:  Pay attention to prevent cold and keep warm, enhance physical fitness
# Y/N :  No
#
# PRED:  lungs
# GT:  Heart
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right
# GT:  Left
# Y/N :  No
#
# PRED:  right upper lobe
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  cva
# GT:  Pulmonary Infiltration
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  heart
# GT:  Breathe
# Y/N :  No
#
# PRED:  dyspnea
# GT:  Chest pain, cough, expectoration
# Y/N :  No
#
# PRED:  lungs
# GT:  Heart
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  chest
# GT:  Chest
# Y/N :  Yes
#
# PRED:  right side
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  right side
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  respiratory
# GT:  Chest
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  white
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  right lung
# GT:  Breathe
# Y/N :  Yes
#
# PRED:  pneumonia
# GT:  Inflammation, malignant tumor, trauma, etc
# Y/N :  No
#
# PRED:  lungs
# GT:  Heart
# Y/N :  No
#
# PRED:  x-ray
# GT:  X-Ray
# Y/N :  Yes
#
# PRED:  anterior-posterior
# GT:  Coronal Plane
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  left side
# GT:  Center
# Y/N :  No
#
# PRED:  right side
# GT:  Lower Left Lung
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  pneumonia and bronchitis
# GT:  Pleural Effusion
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  gray
# GT:  Black
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  lung
# GT:  Breathe
# Y/N :  Yes
#
# PRED:  shortness of breath
# GT:  Chest tightness, dyspnea, chest pain
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  mri
# GT:  CT
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  posterior
# GT:  Center
# Y/N :  No
#
# PRED:  right and left hemispheres of the brain
# GT:  Temporal Lobe
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  gray
# GT:  Gray
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  No
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  none
# GT:  Much
# Y/N :  No
#
# PRED:  brain
# GT:  Brain
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Head
# Y/N :  No
#
# PRED:  above the cerebellum
# GT:  Center
# Y/N :  No
#
# PRED:  brain
# GT:  Head
# Y/N :  Yes
#
# PRED:  brain
# GT:  Head
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  grey
# GT:  White
# Y/N :  No
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  No
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  necrotic tissue
# GT:  Control heartbeat and breathing
# Y/N :  No
#
# PRED:  bladder
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  ct scan
# GT:  CT
# Y/N :  Yes
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  right cerebellum
# GT:  Top
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  brain
# GT:  Head
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  white
# GT:  Gray
# Y/N :  No
#
# PRED:  brain
# GT:  Brain
# Y/N :  Yes
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  cerebellum
# GT:  Cutting, chewing, maintaining facial contour and assisting pronunciation
# Y/N :  No
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  ct scan
# GT:  CT
# Y/N :  Yes
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  the endocrine system
# GT:  Neck
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  spherical
# GT:  Oval
# Y/N :  No
#
# PRED:  lungs
# GT:  Larynx
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  right lobe
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  neck
# GT:  Neck
# Y/N :  Yes
#
# PRED:  right side
# GT:  Under the trachea
# Y/N :  Yes
#
# PRED:  endocrine system
# GT:  Neck
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yellow
# GT:  Black
# Y/N :  No
#
# PRED:  flattened
# GT:  Irregular
# Y/N :  No
#
# PRED:  it is the thyroid gland
# GT:  Gas delivery
# Y/N :  No
#
# PRED:  lungs
# GT:  Trachea
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  brain
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  neck
# GT:  Neck
# Y/N :  Yes
#
# PRED:  right
# GT:  Black Hollow
# Y/N :  No
#
# PRED:  endocrine system
# GT:  Neck
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  flattened
# GT:  Irregular
# Y/N :  No
#
# PRED:  it is the brain
# GT:  Gas delivery
# Y/N :  No
#
# PRED:  stomach
# GT:  Esophagus
# Y/N :  No
#
# PRED:  bladder
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  t2 weighting
# GT:  T2
# Y/N :  Yes
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  right
# GT:  Right
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Head
# Y/N :  No
#
# PRED:  alzheimer's disease and parkinson's disease
# GT:  Brain Edema, Brain Enhancing Tumor
# Y/N :  No
#
# PRED:  two
# GT:  2
# Y/N :  Yes
#
# PRED:  chronic hypointensity
# GT:  Brain embryonic tissue dysplasia, genetic factors, chemical factors
# Y/N :  No
#
# PRED:  coronal t2-weighted mri
# GT:  MRI
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  right renal vein
# GT:  Head
# Y/N :  No
#
# PRED:  right side
# GT:  Upper Left Lobe
# Y/N :  No
#
# PRED:  abdomen
# GT:  Head
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  white
# GT:  White
# Y/N :  Yes
#
# PRED:  metastasis
# GT:  Brain embryonic tissue dysplasia, genetic factors, chemical factors
# Y/N :  No
#
# PRED:  dwi
# GT:  MRI
# Y/N :  Yes
#
# PRED:  t2
# GT:  T2
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  lateral view
# GT:  Head
# Y/N :  No
#
# PRED:  right
# GT:  Left
# Y/N :  No
#
# PRED:  brainstem
# GT:  Head
# Y/N :  Yes
#
# PRED:  cerebellum hyperintensity
# GT:  Brain Edema, Brain Enhancing Tumor, Brain Non-enhancing Tumor
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  3
# GT:  3
# Y/N :  Yes
#
# PRED:  aseptic
# GT:  Visual impairment, vomiting, tinnitus, increased intracranial pressure
# Y/N :  No
#
# PRED:  t2 weighted mri
# GT:  MRI
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  right cerebellum
# GT:  Left Lobe
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  4
# GT:  1
# Y/N :  No
#
# PRED:  none of the above
# GT:  Pharmacotherapy, rehabilitation
# Y/N :  No
#
# PRED:  t2
# GT:  MRI
# Y/N :  Yes
#
# PRED:  yes
# GT:  T2
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right frontal lobe
# GT:  Upper Left Lobe
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  hyperdense
# GT:  Hyperdense
# Y/N :  Yes
#
# PRED:  two
# GT:  1
# Y/N :  No
#
# PRED:  right side
# GT:  Pharmacotherapy, rehabilitation
# Y/N :  No
#
# PRED:  t2-weighted mri scan
# GT:  MRI
# Y/N :  Yes
#
# PRED:  t2 weighted
# GT:  T2
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  brain
# GT:  Head
# Y/N :  Yes
#
# PRED:  right frontal lobe
# GT:  Upper Left Lobe
# Y/N :  No
#
# PRED:  brain
# GT:  Head
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  none of the above
# GT:  Pay attention to dietary hygiene, strengthen physical fitness and avoid brain trauma
# Y/N :  No
#
# PRED:  t2-weighted mri
# GT:  MRI
# Y/N :  Yes
#
# PRED:  t2 weighted
# GT:  T2
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  left frontal lobe
# GT:  Head
# Y/N :  Yes
#
# PRED:  right frontal lobe
# GT:  Upper Right Lobe
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  alzheimer's disease
# GT:  Brain Edema, Brain Non-enhancing Tumor
# Y/N :  No
#
# PRED:  hyperdense
# GT:  Hyperdense
# Y/N :  Yes
#
# PRED:  confusion
# GT:  Visual impairment, vomiting, tinnitus, increased intracranial pressure
# Y/N :  No
#
# PRED:  t2-weighted mri
# GT:  MRI
# Y/N :  Yes
#
# PRED:  t2 weighted
# GT:  T2
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right frontal lobe
# GT:  Upper Right Lobe
# Y/N :  Yes
#
# PRED:  brain
# GT:  Head
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  vaccination
# GT:  Pay attention to dietary hygiene, strengthen physical fitness and avoid brain trauma
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  t2
# GT:  T1
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Head
# Y/N :  Yes
#
# PRED:  right
# GT:  Right
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  alzheimer's disease and multiple sclerosis
# GT:  Brain Edema, Brain Non-enhancing Tumor
# Y/N :  No
#
# PRED:  negligible
# GT:  None
# Y/N :  Yes
#
# PRED:  t2-weighted
# GT:  MRI
# Y/N :  Yes
#
# PRED:  brain
# GT:  Brain
# Y/N :  Yes
#
# PRED:  t2 weighted
# GT:  T2
# Y/N :  Yes
#
# PRED:  brain
# GT:  Brain
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  alzheimer's disease and frontotemporal dementia
# GT:  Brain Edema
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  left frontal lobe
# GT:  Lower Right
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  t2
# GT:  T1
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  cerebellum
# GT:  Head
# Y/N :  Yes
#
# PRED:  left cerebellum
# GT:  Upper Right Lobe
# Y/N :  No
#
# PRED:  cerebellum
# GT:  Head
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  two
# GT:  2
# Y/N :  Yes
#
# PRED:  none
# GT:  None
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  t2 weighting
# GT:  T1
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  right side
# GT:  Left Lobe
# Y/N :  No
#
# PRED:  brain
# GT:  Head
# Y/N :  Yes
#
# PRED:  alzheimer's disease and multiple sclerosis
# GT:  Brain Edema, Brain Enhancing Tumor, Brain Non-enhancing Tumor
# Y/N :  No
#
# PRED:  hyperdense
# GT:  Hyperdense
# Y/N :  Yes
#
# PRED:  stroke
# GT:  Visual impairment, vomiting, tinnitus, increased intracranial pressure
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  t2
# GT:  T1
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  brain
# GT:  Head
# Y/N :  Yes
#
# PRED:  left cerebral hemisphere
# GT:  Lower Left Lobe
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  aneurysm
# GT:  Brain embryonic tissue dysplasia, genetic factors, chemical factors
# Y/N :  No
#
# PRED:  t2-weighted mri
# GT:  MRI
# Y/N :  Yes
#
# PRED:  t2-weighted
# GT:  T1
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Head
# Y/N :  Yes
#
# PRED:  right frontal lobe
# GT:  Left Lobe
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  alzheimer's disease and moyamoyamoto disease
# GT:  Brain Edema, Brain Enhancing Tumor, Brain Non-enhancing Tumor
# Y/N :  No
#
# PRED:  mixed density
# GT:  Hyperdense
# Y/N :  No
#
# PRED:  left hemiparesis
# GT:  Visual impairment, vomiting, tinnitus, increased intracranial pressure
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  left frontal lobe
# GT:  Lower Left Lobe
# Y/N :  No
#
# PRED:  brain
# GT:  Head
# Y/N :  No
#
# PRED:  temozolomide
# GT:  Brain Edema, Brain Enhancing Tumor
# Y/N :  No
#
# PRED:  white
# GT:  White
# Y/N :  Yes
#
# PRED:  two
# GT:  2
# Y/N :  Yes
#
# PRED:  preventive surgery
# GT:  Pay attention to dietary hygiene, strengthen physical fitness and avoid brain trauma
# Y/N :  No
#
# PRED:  t2 weighted
# GT:  MRI
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  left frontal lobe
# GT:  Left Lobe
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  ring enhancing lesion
# GT:  Brain Edema, Brain Non-enhancing Tumor
# Y/N :  No
#
# PRED:  two
# GT:  2
# Y/N :  Yes
#
# PRED:  none
# GT:  None
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  t2
# GT:  T2
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right frontal lobe
# GT:  Left Lobe
# Y/N :  No
#
# PRED:  brain
# GT:  Head
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  none
# GT:  None
# Y/N :  Yes
#
# PRED:  t2 weighted mri
# GT:  MRI
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  Yes
#
# PRED:  t2 weighted
# GT:  T2
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  alzheimer's disease and cerebral small vessel ischemic infarcts
# GT:  None
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  t2 weighted
# GT:  T2
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  left
# GT:  Head
# Y/N :  No
#
# PRED:  left frontal lobe
# GT:  Lower Left Lobe
# Y/N :  No
#
# PRED:  cns
# GT:  Head
# Y/N :  Yes
#
# PRED:  cerebral hemorrhage
# GT:  Brain Edema
# Y/N :  No
#
# PRED:  two
# GT:  1
# Y/N :  No
#
# PRED:  none
# GT:  None
# Y/N :  Yes
#
# PRED:  right
# GT:  Symmetrical to the bottom spine
# Y/N :  No
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  gray
# GT:  Gray
# Y/N :  Yes
#
# PRED:  right kidney
# GT:  Right Kidney
# Y/N :  Yes
#
# PRED:  two
# GT:  6
# Y/N :  No
#
# PRED:  none
# GT:  Much
# Y/N :  No
#
# PRED:  spleen
# GT:  Spleen
# Y/N :  Yes
#
# PRED:  kidneys
# GT:  Kidney
# Y/N :  Yes
#
# PRED:  kidney
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  right side
# GT:  Upper Right
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  smaller lung
# GT:  Lung
# Y/N :  Yes
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  right lobe
# GT:  Biotransformation, detoxification
# Y/N :  No
#
# PRED:  lungs
# GT:  Lung
# Y/N :  Yes
#
# PRED:  liver
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  colon
# GT:  Colon
# Y/N :  Yes
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  to show the location of the mass
# GT:  Breathe
# Y/N :  No
#
# PRED:  small intestine
# GT:  Stomach, Colon
# Y/N :  Yes
#
# PRED:  kidneys
# GT:  Kidney
# Y/N :  Yes
#
# PRED:  liver
# GT:  Yes
# Y/N :  Yes
#
# PRED:  kidney
# GT:  Yes
# Y/N :  Yes
#
# PRED:  liver
# GT:  Small Bowel
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  small bowel
# GT:  Kidney
# Y/N :  No
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  right kidney
# GT:  Absorb nutrients, secrete enzymes, digest food
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  small intestine
# GT:  Yes
# Y/N :  Yes
#
# PRED:  right kidney
# GT:  Symmetrical to the bottom spine
# Y/N :  No
#
# PRED:  liver
# GT:  Small Bowel
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  right
# GT:  Gray
# Y/N :  No
#
# PRED:  smaller liver
# GT:  Liver
# Y/N :  Yes
#
# PRED:  one
# GT:  5
# Y/N :  No
#
# PRED:  diffuse
# GT:  Circular
# Y/N :  No
#
# PRED:  the spleen
# GT:  Absorb nutrients, secrete enzymes, digest food
# Y/N :  No
#
# PRED:  spinal cord
# GT:  Spinal cord
# Y/N :  Yes
#
# PRED:  small intestine
# GT:  Yes
# Y/N :  Yes
#
# PRED:  liver
# GT:  Yes
# Y/N :  Yes
#
# PRED:  right
# GT:  Left
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yellow
# GT:  Gray
# Y/N :  No
#
# PRED:  smaller spleen
# GT:  Spleen
# Y/N :  Yes
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  ellipsoid
# GT:  Oval
# Y/N :  Yes
#
# PRED:  kidney
# GT:  Absorb nutrients, secrete enzymes, digest food
# Y/N :  No
#
# PRED:  spinal cord
# GT:  Spinal cord
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  left
# GT:  Upper Right
# Y/N :  No
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  stomach
# GT:  Liver
# Y/N :  No
#
# PRED:  one
# GT:  0
# Y/N :  No
#
# PRED:  concave
# GT:  Circular
# Y/N :  No
#
# PRED:  liver
# GT:  Improve the body's immunity
# Y/N :  No
#
# PRED:  spleen
# GT:  Spleen
# Y/N :  Yes
#
# PRED:  liver
# GT:  No
# Y/N :  No
#
# PRED:  spleen
# GT:  No
# Y/N :  No
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  Yes
#
# PRED:  above the diaphragm
# GT:  Center
# Y/N :  No
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  white
# GT:  Gray
# Y/N :  No
#
# PRED:  spleen
# GT:  Liver
# Y/N :  No
#
# PRED:  one
# GT:  1
# Y/N :  Yes
#
# PRED:  minimal
# GT:  Much
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  t2 weighted mri
# GT:  MRI
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  Yes
#
# PRED:  t2
# GT:  T2
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  Yes
#
# PRED:  cerebellum
# GT:  Brain
# Y/N :  Yes
#
# PRED:  yes
# GT:  Yes
# Y/N :  Yes
#
# PRED:  alzheimer's disease and multiple sclerosis
# GT:  Brain Tumor, Brain Edema
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  left cerebellum
# GT:  Lower Left
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Abdomen
# Y/N :  Yes
#
# PRED:  left
# GT:  Top
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  yes
# GT:  No
# Y/N :  No
#
# PRED:  smaller liver
# GT:  Esophagus
# Y/N :  No
#
# PRED:  one
# GT:  2
# Y/N :  No
#
# PRED:  none
# GT:  Much
# Y/N :  No
#
# PRED:  small intestine
# GT:  Esophagus
# Y/N :  No
#
# PRED:  lung
# GT:  No
# Y/N :  No
#
# PRED:  liver
# GT:  Yes
# Y/N :  Yes
#
# PRED:  axial
# GT:  Transverse Plane
# Y/N :  No
#
# PRED:  lung
# GT:  Right Lung
# Y/N :  No
#
# PRED:  no
# GT:  Yes
# Y/N :  No
#
# PRED:  no
# GT:  No
# Y/N :  Yes
#
# PRED:  apex
# GT:  Black
# Y/N :  No
#
# PRED:  esophagus
# GT:  Esophagus
# Y/N :  Yes
#
# PRED:  one
# GT:  4
# Y/N :  No
#
# PRED:  lung
# GT:  Promote blood flow
# Y/N :  No
#
# PRED:  heart
# GT:  No
# Y/N :  No
#
# PRED:  lung
# GT:  No
# Y/N :  No
#
# PRED:  ct
# GT:  CT
# Y/N :  Yes
#
# PRED:  abdomen
# GT:  Pelvic Cavity
# Y/N :  No
#
# PRED:  above the mass
# GT:  Bottom
# Y/N :  No
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[138], line 20
#      19 try:
# ---> 20     corrected_pred = generate_text(input_text)
#      21 except e:
#
# Cell In[133], line 7, in generate_text(txt)
#       6 response = multimodal_model.generate_content(txt)
# ----> 7 return response.text
#
# File ~/miniconda3/lib/python3.11/site-packages/vertexai/generative_models/_generative_models.py:1413, in GenerationResponse.text(self)
#    1412     raise ValueError("Response has no candidates (and no text).")
# -> 1413 return self.candidates[0].text
#
# File ~/miniconda3/lib/python3.11/site-packages/vertexai/generative_models/_generative_models.py:1470, in Candidate.text(self)
#    1468 @property
#    1469 def text(self) -> str:
# -> 1470     return self.content.text
#
# File ~/miniconda3/lib/python3.11/site-packages/vertexai/generative_models/_generative_models.py:1541, in Content.text(self)
#    1540 if not self.parts:
# -> 1541     raise AttributeError("Content has no parts.")
#    1542 return self.parts[0].text
#
# AttributeError: Content has no parts.
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[138], line 21
#      19 try:
#      20     corrected_pred = generate_text(input_text)
# ---> 21 except e:
#      22     print(e)
#      23     corrected_pred = 'No'
#
# NameError: name 'e' is not defined

# %%
yes_no = np.array(yes_no)

# %%
yes_no[0] = 'Yes'

# %%
(sum(yes_no == 'Yes') / len(yes_no)) * 100

# %%
open_closed = []

# %%
for i, obj in enumerate(data):
    if obj['answer_type'] == 'OPEN': 
        open_closed.append(yes_no[i])

# %%
open_closed = np.array(open_closed)

# %%
(sum(open_closed == 'Yes') / len(open_closed)) * 100

# %% [markdown]
# # cnt = 0
# for obj in data:
#     if obj['answer_type'] == 'OPEN':
#         cnt += 1

# %%
cnt
# Out:
# 645

# %%
((179/451)*64.39) + ((272/451)*81.98)
# Out:
# 74.99860310421286

# %%
((645/1061)*84.71) + ((416/1061)*83.17)
# Out:
# 84.10619227144204

# %%
# !pip install rouge-score
# Out:
# Requirement already satisfied: rouge-score in /home/sabbam0a/miniconda3/lib/python3.11/site-packages (0.1.2)
# Requirement already satisfied: absl-py in /home/sabbam0a/miniconda3/lib/python3.11/site-packages (from rouge-score) (2.1.0)
# Requirement already satisfied: nltk in /home/sabbam0a/miniconda3/lib/python3.11/site-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in /home/sabbam0a/miniconda3/lib/python3.11/site-packages (from rouge-score) (1.26.2)
# Requirement already satisfied: six>=1.14.0 in /home/sabbam0a/miniconda3/lib/python3.11/site-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /home/sabbam0a/miniconda3/lib/python3.11/site-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /home/sabbam0a/miniconda3/lib/python3.11/site-packages (from nltk->rouge-score) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/sabbam0a/miniconda3/lib/python3.11/site-packages (from nltk->rouge-score) (2023.12.25)
# Requirement already satisfied: tqdm in /home/sabbam0a/miniconda3/lib/python3.11/site-packages (from nltk->rouge-score) (4.65.0)

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize
import Levenshtein

# %%
bleu_scores = []
meteor_scores = []
levenshtein_similarities = []

for i, obj in enumerate(data):
    real_answer = obj['gt']
    llm_message = obj['pred']
    
    # BLEU score
    bleu_score = sentence_bleu([real_answer.split()], 
                               llm_message.split(), 
                               smoothing_function=SmoothingFunction().method1)
    bleu_scores.append(bleu_score)
    
    # METEOR score
    meteor_score_ = meteor_score([real_answer.split()], llm_message.split())
    meteor_scores.append(meteor_score_)
    
    
    # Levenshtein similarity
    levenshtein_distance = Levenshtein.distance(real_answer, llm_message)
    max_len = max(len(real_answer), len(llm_message))
    levenshtein_similarity = 1 - (levenshtein_distance / max_len)
    levenshtein_similarities.append(levenshtein_similarity)

# %%
bleu_scores = np.array(bleu_scores)
meteor_scores = np.array(meteor_scores)
levenshtein_similarities = np.array(levenshtein_similarities)
print('bleu_scores', bleu_scores.mean() * 100)
print('meteor_scores', meteor_scores.mean() * 100)
print('levenshtein_similarities', levenshtein_similarities.mean() * 100)
# Out:
# bleu_scores 2.920153483923626
# meteor_scores 24.983686717127775
# levenshtein_similarities 39.32752186932412

# %%
bleu_scores_oc = []
meteor_scores_oc = []
levenshtein_similarities_oc = []

for i, obj in enumerate(data):
    if obj['answer_type'] == 'CLOSED': 
        bleu_scores_oc.append(bleu_scores[i])
        meteor_scores_oc.append(meteor_scores[i])
        levenshtein_similarities_oc.append(levenshtein_similarities[i])
        
bleu_scores_oc = np.array(bleu_scores_oc)    
meteor_scores_oc = np.array(meteor_scores_oc)    
levenshtein_similarities_oc = np.array(levenshtein_similarities_oc)  

print('bleu_scores', bleu_scores_oc.mean() * 100)
print('meteor_scores', meteor_scores_oc.mean() * 100)
print('levenshtein_similarities', levenshtein_similarities_oc.mean() * 100)
# Out:
# bleu_scores 3.20351805484953
# meteor_scores 30.594743878412604
# levenshtein_similarities 42.372052987861814
